# %% [markdown]
# # Study of Passengers Feedback and Overall Experiences On Airlines

# %% [markdown]
# ## Aim

# %% [markdown]
# * The aim of this study is to to identify the problems and issueswhich are been faced by the passengers who are traveling, thereby helps inenhancing their services for the future growth of the airline companies.
# * To develop a predictive model to identify the level ofsatisfaction of the passengers of the airline companies.

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# * Gender: Gender of the passengers (Female, Male)
#
# * Customer Type: The customer type (Loyal customer, disloyal customer)
#
# * Age: The actual age of the passengers
#
# * Type of Travel: Purpose of the flight of the passengers (Personal Travel, Business Travel)
#
# * Class: Travel class in the plane of the passengers (Business, Eco, Eco Plus)
#
# * Flight distance: The flight distance of this journey
#
# * Inflight wifi service: Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)
#
# * Departure/Arrival time convenient: Satisfaction level of Departure/Arrival time convenient
#
# * Ease of Online booking: Satisfaction level of online booking
#
# * Gate location: Satisfaction level of Gate location
#
# * Food and drink: Satisfaction level of Food and drink
#
# * Online boarding: Satisfaction level of online boarding
#
# * Seat comfort: Satisfaction level of Seat comfort
#
# * Inflight entertainment: Satisfaction level of inflight entertainment
#
# * On-board service: Satisfaction level of On-board service
#
# * Leg room service: Satisfaction level of Leg room service
#
# * Baggage handling: Satisfaction level of baggage handling
#
# * Check-in service: Satisfaction level of Check-in service
#
# * Inflight service: Satisfaction level of inflight service
#
# * Cleanliness: Satisfaction level of Cleanliness
#
# * Departure Delay in Minutes: Minutes delayed when departure
#
# * Arrival Delay in Minutes: Minutes delayed when Arrival
#
# * Satisfaction: Passengers satisfaction level(Satisfaction, neutral or dissatisfaction)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('airline.csv')

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0                  0           0   70172    Male     Loyal Customer   13
# 1                  1           1    5047    Male  disloyal Customer   25
# 2                  2           2  110028  Female     Loyal Customer   26
# 3                  3           3   24026  Female     Loyal Customer   25
# 4                  4           4  119299    Male     Loyal Customer   61
# ...              ...         ...     ...     ...                ...  ...
# 129875        129875       25971   78463    Male  disloyal Customer   34
# 129876        129876       25972   71167    Male     Loyal Customer   23
# 129877        129877       25973   37675  Female     Loyal Customer   17
# 129878        129878       25974   90086    Male     Loyal Customer   14
# 129879        129879       25975   34799  Female     Loyal Customer   42
#
#          Type of Travel     Class  Flight Distance  Inflight wifi service  \
# ...

# %% [markdown]
# ### Dataset has
# * 129880 -> rows
# * 26 -> columns

# %% [markdown]
# ### Dropping the unwanted column

# %%
df.drop(columns=['Unnamed: 0.1','Unnamed: 0'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Inflight wifi service              129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Ease of Online booking             129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  129880.000000  129880.000000    129880.000000          129880.000000
# mean    64940.500000      39.427957      1190.316392               2.728696
# std     37493.270818      15.119360       997.452477               1.329340
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32470.750000      27.000000       414.000000               2.000000
# 50%     64940.500000      40.000000       844.000000               3.000000
# 75%     97410.250000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# ...

# %% [markdown]
# ### Id column is not required for the EDA and Model prediction

# %%
df.drop(columns=['id'],inplace=True)

# %% [markdown]
# ### Checking Missing values :

# %%
df.isna().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# ...

# %%
median=df['Arrival Delay in Minutes'].median()

# %%
df['Arrival Delay in Minutes']=df['Arrival Delay in Minutes'].fillna(median)

# %%
df.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# ### All the missing values are been handled

# %% [markdown]
# ### Changing column names to lower case

# %%
new=[]
for i in df.columns:
    new.append(i.lower())

# %%
df.columns=new

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df
# Out:
#         gender      customer_type  age   type_of_travel     class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 129875    Male  disloyal Customer   34  Business travel  Business
# 129876    Male     Loyal Customer   23  Business travel  Business
# 129877  Female     Loyal Customer   17  Personal Travel       Eco
# 129878    Male     Loyal Customer   14  Business travel  Business
# 129879  Female     Loyal Customer   42  Personal Travel       Eco
#
#         flight_distance  inflight_wifi_service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [gender, customer_type, age, type_of_travel, class, flight_distance, inflight_wifi_service, departure/arrival_time_convenient, ease_of_online_booking, gate_location, food_and_drink, online_boarding, seat_comfort, inflight_entertainment, on-board_service, leg_room_service, baggage_handling, checkin_service, inflight_service, cleanliness, departure_delay_in_minutes, arrival_delay_in_minutes, satisfaction]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ## There are no duplicated records in the dataset

# %% [markdown]
# ## Univariate Analysis

# %%
sns.countplot(data=df,x=df.satisfaction,palette='ocean')
plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'customer_type', 'age', 'type_of_travel', 'class',
#        'flight_distance', 'inflight_wifi_service',
#        'departure/arrival_time_convenient', 'ease_of_online_booking',
#        'gate_location', 'food_and_drink', 'online_boarding', 'seat_comfort',
#        'inflight_entertainment', 'on-board_service', 'leg_room_service',
#        'baggage_handling', 'checkin_service', 'inflight_service',
#        'cleanliness', 'departure_delay_in_minutes', 'arrival_delay_in_minutes',
#        'satisfaction'],
#       dtype='object')

# %%
fig, axes = plt.subplots(5, 4, figsize = (20, 20))
sns.countplot(data=df,x=df.gender,palette='ocean',ax=axes[0,0])
sns.countplot(data=df,x=df.customer_type,palette='ocean',ax=axes[0,1])
sns.countplot(data=df,x=df.age,palette='ocean',ax=axes[0,2])
sns.countplot(data=df,x=df.type_of_travel,palette='ocean',ax=axes[0,3])
sns.countplot(data=df,x=df['class'],palette='ocean',ax=axes[1,0])
sns.countplot(data=df,x=df.flight_distance,palette='ocean',ax=axes[1,1])
sns.countplot(data=df,x=df.inflight_wifi_service,palette='ocean',ax=axes[1,2])
sns.countplot(data=df,x=df.ease_of_online_booking,palette='ocean',ax=axes[1,3])
sns.countplot(data=df,x=df.gate_location,palette='ocean',ax=axes[2,0])
sns.countplot(data=df,x=df.food_and_drink,palette='ocean',ax=axes[2,1])
sns.countplot(data=df,x=df.online_boarding,palette='ocean',ax=axes[2,2])
sns.countplot(data=df,x=df.seat_comfort,palette='ocean',ax=axes[2,3])
sns.countplot(data=df,x=df.inflight_entertainment,palette='ocean',ax=axes[3,0])
sns.countplot(data=df,x=df['on-board_service'],palette='ocean',ax=axes[3,1])
sns.countplot(data=df,x=df.leg_room_service,palette='ocean',ax=axes[3,2])
sns.countplot(data=df,x=df.baggage_handling,palette='ocean',ax=axes[3,3])
sns.countplot(data=df,x=df.checkin_service,palette='ocean',ax=axes[4,0])
sns.countplot(data=df,x=df.inflight_service,palette='ocean',ax=axes[4,1])
sns.countplot(data=df,x=df.cleanliness,palette='ocean',ax=axes[4,2])
sns.countplot(data=df,x=df['departure/arrival_time_convenient'],palette='ocean',ax=axes[4,3])
plt.show()

# %% [markdown]
# * There are equal no of male and female Passengers.
# * Airlines has many Loyal Customer.
# * Passengers travelling through airlines age range from age 22 to 60.
# * Business travel is more popular than personal travel.
# * Business and Economy are the two most popular classes.
# * Ease of online booking and Wifi Service have same no of ratings from the passengers.
# * People have mixed reviews regarding most of the other facilites.

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=[25,12])
sns.countplot(data=df,x=df.age,hue=df['class'],hue_order=['Eco Plus','Eco','Business'])
plt.show()

# %% [markdown]
# * Regular customers mainly buy business class for themselves.

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.inflight_wifi_service,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.inflight_wifi_service,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.inflight_wifi_service,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %% [markdown]
# * Economy class passengers are mostly rated with 2 or 3out of 5.
# * There are more dissatisfaction for Wifi Services, airlines should reduce the internet charges to make the passengers to fly back with the same airlines back in future.

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.ease_of_online_booking,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.ease_of_online_booking,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.ease_of_online_booking,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %% [markdown]
# * Most of the passengers are dissatisfied with the online booking method. so the Airline company should make some changes in the UI of online booking to make the passengers buy the tickets easily.

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.gate_location,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.gate_location,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.gate_location,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %% [markdown]
# * Gate location should also been taken into consideration to bring the customers back to same airlines.

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.food_and_drink,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.food_and_drink,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.food_and_drink,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %% [markdown]
# * Food and Drink are the most important factor for passengers to fly back in that airlines but majority of customers have given low ratings.

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.online_boarding,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.online_boarding,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.online_boarding,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.seat_comfort,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.seat_comfort,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.seat_comfort,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.inflight_entertainment,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.inflight_entertainment,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.inflight_entertainment,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.leg_room_service,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.leg_room_service,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.leg_room_service,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %% [markdown]
# * Passengers are feeling good with Seat comfort, legroom facility, and inflight entertainment.

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.baggage_handling,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.baggage_handling,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.baggage_handling,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %% [markdown]
# * Baggage handling is taken good care for people who are traveling in buisness class.
# * Extra consideration should been taken care for people in Economy class peoples also.

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.checkin_service,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.checkin_service,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.checkin_service,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %% [markdown]
# * Check-in time or boarding pass for passengers is taking more time to get into the flight. Airlines must fasten up the check-in time or should provide extra counters for check-in purposes so that waiting time for the passengers in the queue will be reduced.

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df.cleanliness,hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df.cleanliness,hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df.cleanliness,hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 7))
sns.countplot(data=df,x=df['departure/arrival_time_convenient'],hue=df['class'],palette= 'ocean',ax=axes[0])
sns.countplot(data=df,x=df['departure/arrival_time_convenient'],hue=df['gender'],palette= 'ocean',ax=axes[1])
sns.countplot(data=df,x=df['departure/arrival_time_convenient'],hue=df['satisfaction'],palette= 'ocean',ax=axes[2])
plt.show()

# %% [markdown]
# * Passengers consider mostly looking into the depature&arrival time for flying with the same airlines back. so, Airlines must maintain a proper scheduled time.

# %% [markdown]
# ## Major Factors which causes the passenger for dissatisfaction are:
# * Food and Drink
# * inflight wifi service
# * ease of online booking
# * baggage handling
# * check in service
# * inflight service
# * gate location
# * depature/arrival time convenient

# %%
fig, axes = plt.subplots(4, 2, figsize = (17, 15))
sns.countplot(data=df,x=df.food_and_drink,hue=df['satisfaction'],palette= 'viridis',ax=axes[0,0])
sns.countplot(data=df,x=df.inflight_wifi_service,hue=df['satisfaction'],palette= 'viridis',ax=axes[0,1])
sns.countplot(data=df,x=df.ease_of_online_booking,hue=df['satisfaction'],palette= 'viridis',ax=axes[1,0])
sns.countplot(data=df,x=df.baggage_handling,hue=df['satisfaction'],palette= 'viridis',ax=axes[1,1])
sns.countplot(data=df,x=df.checkin_service,hue=df['satisfaction'],palette= 'viridis',ax=axes[2,0])
sns.countplot(data=df,x=df.inflight_service,hue=df['satisfaction'],palette= 'viridis',ax=axes[2,1])
sns.countplot(data=df,x=df.gate_location,hue=df['satisfaction'],palette= 'viridis',ax=axes[3,0])
sns.countplot(data=df,x=df['departure/arrival_time_convenient'],hue=df['satisfaction'],palette= 'viridis',ax=axes[3,1])
# Out:
# <AxesSubplot:xlabel='departure/arrival_time_convenient', ylabel='count'>

# %% [markdown]
# ## Multicollinearity

# %%
plt.figure(figsize=[15,10])
sns.heatmap(data=df.corr(),annot=True)
plt.show()

# %%
sns.scatterplot(data=df,x=df.departure_delay_in_minutes,y=df.arrival_delay_in_minutes)
plt.show()

# %% [markdown]
# * Departure Delay and Arrival delay are heavily correlated with each other, therefore one of them should be dropped.

# %%
df.drop(columns=['departure_delay_in_minutes'],inplace=True)

# %%
df
# Out:
#         gender      customer_type  age   type_of_travel     class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 129875    Male  disloyal Customer   34  Business travel  Business
# 129876    Male     Loyal Customer   23  Business travel  Business
# 129877  Female     Loyal Customer   17  Personal Travel       Eco
# 129878    Male     Loyal Customer   14  Business travel  Business
# 129879  Female     Loyal Customer   42  Personal Travel       Eco
#
#         flight_distance  inflight_wifi_service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %% [markdown]
# ## Model Building

# %%
dep=df.iloc[:,:-1]

# %% [markdown]
# ### Target encoding

# %%
dep['gender'].replace({'Male':0,'Female':1},inplace=True)

# %%
dep['customer_type'].replace({'Loyal Customer':0,'disloyal Customer':1},inplace=True)

# %%
dep['type_of_travel'].replace({'Personal Travel':0,'Business travel':1},inplace=True)

# %%
dep['class'].replace({'Eco':0,'Eco Plus':1,'Business':2},inplace=True)

# %% [markdown]
# ## Note:
# ### Gender
#    * Male -> 0
#    * Female -> 1
#
# ### Customer type
#    * Loyal customer -> 0
#    * disloyal customer ->1
#
# ### Type of travel
#    * Personal travel -> 0
#    * Business travel -> 1
#
# ### Class
#    * Eco -> 0
#    * Eco Plus -> 1
#    * Business -> 2

# %%
indep=df.iloc[:,-1]

# %%
indep.replace({'neutral or dissatisfied':0,'satisfied':1},inplace=True)

# %% [markdown]
# ### neutral or dissatisfied ->0
# ### satisfied ->1

# %%
dep
# Out:
#         gender  customer_type  age  type_of_travel  class  flight_distance  \
# 0            0              0   13               0      1              460
# 1            0              1   25               1      2              235
# 2            1              0   26               1      2             1142
# 3            1              0   25               1      2              562
# 4            0              0   61               1      2              214
# ...        ...            ...  ...             ...    ...              ...
# 129875       0              1   34               1      2              526
# 129876       0              0   23               1      2              646
# 129877       1              0   17               0      0              828
# 129878       0              0   14               1      2             1127
# 129879       1              0   42               0      0              264
#
#         inflight_wifi_service  departure/arrival_time_convenient  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(dep,indep,test_size=0.3,random_state=42)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (90916, 21)
# (38964, 21)
# (90916,)
# (38964,)

# %% [markdown]
# ##  Handling the imbalance in the dataset

# %%
from imblearn.over_sampling import SMOTE

# %%
from collections import Counter
counter = Counter(ytrain)
print('Before',counter)

smt = SMOTE()

xtrain_sm,ytrain_sm = smt.fit_resample(xtrain,ytrain)

counter = Counter(ytrain_sm)
print('After',counter)
# Out:
# Before Counter({0: 51473, 1: 39443})
# After Counter({0: 51473, 1: 51473})

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()
xtrain_sm[['flight_distance','arrival_delay_in_minutes']]=minmax.fit_transform(xtrain_sm[['flight_distance','arrival_delay_in_minutes']])

# %%
xtrain_sm
# Out:
#         gender  customer_type  age  type_of_travel  class  flight_distance  \
# 0            0              0   31               0      0         0.046042
# 1            1              0   18               0      0         0.309774
# 2            1              0   47               1      0         0.041599
# 3            0              0   33               0      1         0.018982
# 4            0              0   10               0      0         0.174273
# ...        ...            ...  ...             ...    ...              ...
# 102941       0              0   20               1      1         0.235057
# 102942       0              0   37               1      2         0.135097
# 102943       0              0   50               1      2         0.656704
# 102944       0              0   61               1      0         0.106018
# 102945       1              0   49               1      2         0.352585
#
#         inflight_wifi_service  departure/arrival_time_convenient  \
# ...

# %%
xtest
# Out:
#         gender  customer_type  age  type_of_travel  class  flight_distance  \
# 103044       0              0   66               0      0             1678
# 43282        1              0   38               1      2              954
# 65543        1              0   38               1      0              189
# 65083        1              0   32               0      0              175
# 76496        0              0   33               1      2             1990
# ...        ...            ...  ...             ...    ...              ...
# 32347        0              0   20               1      1              290
# 123061       1              0   52               0      0             1844
# 74700        0              0   52               1      2             1578
# 54997        0              0   59               0      0              710
# 107396       0              0   31               1      0              631
#
#         inflight_wifi_service  departure/arrival_time_convenient  \
# ...

# %%
model=minmax.fit(xtest[['flight_distance','arrival_delay_in_minutes']])

# %%
model
# Out:
# MinMaxScaler()

# %%
scaled=model.transform(xtest[['flight_distance','arrival_delay_in_minutes']])

# %%
scaled
# Out:
# array([[0.33259289, 0.        ],
#        [0.18638934, 0.        ],
#        [0.0319063 , 0.        ],
#        ...,
#        [0.31239903, 0.01767677],
#        [0.13711632, 0.00757576],
#        [0.12116317, 0.        ]])

# %%
flightdistance=scaled[:,0]

# %%
arrival=scaled[:,1]

# %%
xtest
# Out:
#         gender  customer_type  age  type_of_travel  class  flight_distance  \
# 103044       0              0   66               0      0             1678
# 43282        1              0   38               1      2              954
# 65543        1              0   38               1      0              189
# 65083        1              0   32               0      0              175
# 76496        0              0   33               1      2             1990
# ...        ...            ...  ...             ...    ...              ...
# 32347        0              0   20               1      1              290
# 123061       1              0   52               0      0             1844
# 74700        0              0   52               1      2             1578
# 54997        0              0   59               0      0              710
# 107396       0              0   31               1      0              631
#
#         inflight_wifi_service  departure/arrival_time_convenient  \
# ...

# %%
xtest['flight_distance']=flightdistance

# %%
xtest['arrival_delay_in_minutes']=arrival

# %%
Final_Report=pd.DataFrame()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression()

# %%
log_model.fit(xtrain_sm,ytrain_sm)
# Out:
# C:\Users\kumut\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log_predict=log_model.predict(xtest)

# %%
from sklearn.metrics import classification_report, accuracy_score,recall_score, roc_auc_score,precision_score,accuracy_score,f1_score

# %%
Report = classification_report(ytest,log_predict)

# %%
accuracy_score(ytest,log_predict)
# Out:
# 0.8654398932347809

# %% [markdown]
# ### Logistic Model Evaluation

# %%
print(Report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88     21979
#            1       0.84      0.86      0.85     16985
#
#     accuracy                           0.87     38964
#    macro avg       0.86      0.86      0.86     38964
# weighted avg       0.87      0.87      0.87     38964

# %%
scikitplot.metrics.plot_confusion_matrix(ytest, log_predict, figsize=(6,6), cmap= 'YlGnBu');

# %%
logistic=pd.Series({'Model': "Logistic Regression",
                'Accuracy Score':accuracy_score(ytest, log_predict).round(2),
                 'Precision Score': precision_score(ytest, log_predict),
                 'Recall Score': recall_score(ytest, log_predict),
                 'F1 Score' : f1_score(ytest, log_predict),
                 'ROC Score' : roc_auc_score(ytest, log_predict),
                 })

# %%
logistic
# Out:
# Model              Logistic Regression
# Accuracy Score                 0.86544
# Precision Score               0.835754
# Recall Score                  0.860406
# F1 Score                      0.847901
# ROC Score                     0.864868
# dtype: object

# %% [markdown]
# ## Decesion tree

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
Dt_model=DecisionTreeClassifier()

# %%
Dt_model.fit(xtrain_sm,ytrain_sm)
# Out:
# DecisionTreeClassifier()

# %%
Dt_predict=Dt_model.predict(xtest)

# %%
accuracy_score(ytest,Dt_predict)
# Out:
# 0.9385586695411149

# %%
Dt_Report = classification_report(ytest,Dt_predict)

# %% [markdown]
# ### Decision Tree Evaluation

# %%
print(Dt_Report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94     21979
#            1       0.92      0.94      0.93     16985
#
#     accuracy                           0.94     38964
#    macro avg       0.94      0.94      0.94     38964
# weighted avg       0.94      0.94      0.94     38964

# %%
scikitplot.metrics.plot_confusion_matrix(ytest, Dt_predict, figsize=(6,6), cmap= 'YlGnBu');

# %%
Decision=pd.Series({'Model': "Decision Tree",
                'Accuracy Score':accuracy_score(ytest, Dt_predict).round(2),
                 'Precision Score': precision_score(ytest, Dt_predict),
                 'Recall Score': recall_score(ytest, Dt_predict),
                 'F1 Score' : f1_score(ytest, Dt_predict),
                 'ROC Score' : roc_auc_score(ytest, Dt_predict),
                 })

# %%
Decision
# Out:
# Model              Decision Tree
# Accuracy Score          0.938559
# Precision Score         0.916671
# Recall Score            0.944951
# F1 Score                0.930597
# ROC Score               0.939285
# dtype: object

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rf_model=RandomForestClassifier(n_estimators=100)

# %%
Rf_model.fit(xtrain_sm,ytrain_sm)
# Out:
# RandomForestClassifier()

# %%
Rf_predict=Rf_model.predict(xtest)

# %%
accuracy_score(ytest,Rf_predict)
# Out:
# 0.9589877835951134

# %%
Rf_Report=classification_report(ytest,Rf_predict)

# %% [markdown]
# ### Random Forest Evaluation

# %%
print(Rf_Report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     21979
#            1       0.96      0.95      0.95     16985
#
#     accuracy                           0.96     38964
#    macro avg       0.96      0.96      0.96     38964
# weighted avg       0.96      0.96      0.96     38964

# %%
scikitplot.metrics.plot_confusion_matrix(ytest, Rf_predict, figsize=(6,6), cmap= 'YlGnBu');

# %%
Random=pd.Series({'Model': "Random Forest",
                'Accuracy Score':accuracy_score(ytest, Rf_predict).round(2),
                 'Precision Score': precision_score(ytest, Rf_predict),
                 'Recall Score': recall_score(ytest, Rf_predict),
                 'F1 Score' : f1_score(ytest, Rf_predict),
                 'ROC Score' : roc_auc_score(ytest, Rf_predict),
                 })

# %%
Random
# Out:
# Model              Random Forest
# Accuracy Score          0.958988
# Precision Score         0.957647
# Recall Score            0.947836
# F1 Score                0.952716
# ROC Score               0.957721
# dtype: object

# %% [markdown]
# ## Xgboost

# %%
import xgboost as xgb

# %%
xgb_model=xgb.XGBClassifier()

# %%
xgb_model.fit(xtrain_sm,ytrain_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xgb_predict=xgb_model.predict(xtest)

# %%
xgb_Report=classification_report(ytest,xgb_predict)

# %%
accuracy_score(ytest,xgb_predict)
# Out:
# 0.9550610820244329

# %% [markdown]
# ### XGBboost Evaluation

# %%
print(xgb_Report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96     21979
#            1       0.94      0.96      0.95     16985
#
#     accuracy                           0.96     38964
#    macro avg       0.95      0.96      0.95     38964
# weighted avg       0.96      0.96      0.96     38964

# %%
import scikitplot

# %%
scikitplot.metrics.plot_confusion_matrix(ytest, xgb_predict, figsize=(6,6), cmap= 'YlGnBu');

# %%
xgb=pd.Series({'Model': "XGBboost Classifier",
                'Accuracy Score':accuracy_score(ytest, xgb_predict).round(2),
                 'Precision Score': precision_score(ytest, xgb_predict),
                 'Recall Score': recall_score(ytest, xgb_predict),
                 'F1 Score' : f1_score(ytest, xgb_predict),
                 'ROC Score' : roc_auc_score(ytest, xgb_predict),
                 })

# %% [markdown]
# ### Knn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
accuracy = []
for i in range(1,15):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(xtrain_sm,ytrain_sm)
    pred_i = knn.predict(xtest)
    accuracy_i = accuracy_score(ytest, pred_i)
    accuracy.append(accuracy_i)

# %%
plt.figure(figsize=(15,6))
plt.plot(range(1,15, 1), accuracy, color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.show()

# %%
knn_model = KNeighborsClassifier(n_neighbors = 7)
knn_model.fit(xtrain_sm, ytrain_sm)
knn_predict = knn.predict(xtest)

# %%
knn_Report=classification_report(ytest,knn_predict)

# %% [markdown]
# ### Knn Evaluation

# %%
print(knn_Report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92     21979
#            1       0.92      0.88      0.90     16985
#
#     accuracy                           0.91     38964
#    macro avg       0.91      0.91      0.91     38964
# weighted avg       0.91      0.91      0.91     38964

# %%
scikitplot.metrics.plot_confusion_matrix(ytest, knn_predict, figsize=(6,6), cmap= 'YlGnBu');

# %%
knn=pd.Series({'Model': "KNeighborsClassifier",
                'Accuracy Score':accuracy_score(ytest, knn_predict).round(2),
                 'Precision Score': precision_score(ytest, knn_predict),
                 'Recall Score': recall_score(ytest, knn_predict),
                 'F1 Score' : f1_score(ytest, knn_predict),
                 'ROC Score' : roc_auc_score(ytest, knn_predict),
                 })

# %%
Final_Report['Logistic Regression']=logistic
Final_Report['Decision Tree']=Decision
Final_Report['Random Forest']=Random
Final_Report['XGBboost Classifier']=xgb 
Final_Report['KNeighborsClassifier']=knn

# %%
Final_Report
# Out:
#                  Logistic Regression  Decision Tree  Random Forest  \
# Model            Logistic Regression  Decision Tree  Random Forest
# Accuracy Score                  0.87           0.94           0.96
# Precision Score             0.835754       0.916671       0.957647
# Recall Score                0.860406       0.944951       0.947836
# F1 Score                    0.847901       0.930597       0.952716
# ROC Score                   0.864868       0.939285       0.957721
#
#                  XGBboost Classifier  KNeighborsClassifier
# Model            XGBboost Classifier  KNeighborsClassifier
# Accuracy Score                  0.96                  0.91
# Precision Score             0.941565              0.919247
# Recall Score                0.956256              0.879305
# F1 Score                    0.948854              0.898832
# ROC Score                   0.955197              0.909806
